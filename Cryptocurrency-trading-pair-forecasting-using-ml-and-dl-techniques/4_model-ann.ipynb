# %% [markdown]
# ## 4. Model - Artificial Neural Networks (ANN)

# %%
import pandas as pd 
import numpy as np 
import yfinance as yf 
import matplotlib.dates as mdates 
import matplotlib.pyplot as plt 
# %matplotlib inline 
plt.style.use('seaborn-v0_8-dark') 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### 1. Fetching Data

# %%
start_date = '2018-01-01'
end_date = '2019-09-01' 

assets = 'BTC-USD'

# %%
btc_adjClose = pd.DataFrame() 

btc_adjClose['Adj_Close'] = yf.download('BTC-USD',start=start_date,end=end_date)['Adj Close']
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# #### 2. Splitting data into training and testing dataset

# %%
btc_train = btc_adjClose[:487] 
btc_test = btc_adjClose[486:] 

print(f'Shape of train after splitting : {btc_train.shape}') 
print(f'Shape of test after splitting : {btc_test.shape}')
# Out:
# Shape of train after splitting : (487, 1)
# Shape of test after splitting : (122, 1)

# %% [markdown]
# #### 3. Scaling the data for training and testing

# %%
from sklearn.preprocessing import MinMaxScaler  
np.random.seed(0) 
scaler = MinMaxScaler(feature_range=(0,1)) 
scaled_data = scaler.fit_transform(btc_adjClose)

# %% [markdown]
# #### 4. Reshaping the scaled data for ANN Network

# %%
x_train, y_train = [],[] 
for i in range(80,len(btc_train)):
    x_train.append(scaled_data[i-80:i,0]) 
    y_train.append(scaled_data[i,0]) 
x_train, y_train = np.array(x_train), np.array(y_train) 

x_train = np.reshape(x_train,(x_train.shape[0],x_train.shape[1])) 
print('Shape of x_train: ',x_train.shape)
print('Shape of y_train: ',y_train.shape)
# Out:
# Shape of x_train:  (407, 80)
# Shape of y_train:  (407,)

# %% [markdown]
# #### 5. Defining ANN Network

# %%
from keras.models import Sequential 
from keras.layers import Dense
# Out:
# WARNING:tensorflow:From C:\Users\vidya\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
model = Sequential() 
model.add(Dense(units=13,kernel_initializer='uniform',activation='relu',input_dim=80)) 
model.add(Dense(units=13,kernel_initializer='uniform',activation='relu')) 
model.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid')) 
model.compile(optimizer='adam',loss='mean_squared_error',metrics=['accuracy'])  
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\vidya\AppData\Roaming\Python\Python311\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\vidya\AppData\Roaming\Python\Python311\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 13)                1053
#
#  dense_1 (Dense)             (None, 13)                182
#
#  dense_2 (Dense)             (None, 1)                 14
#
# =================================================================
# Total params: 1249 (4.88 KB)
# Trainable params: 1249 (4.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### 6. Training the model

# %%
model.fit(x_train,y_train,batch_size=1,epochs=13,verbose=2)
# Out:
# Epoch 1/13
# WARNING:tensorflow:From C:\Users\vidya\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\vidya\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 407/407 - 1s - loss: 0.0519 - accuracy: 0.0025 - 900ms/epoch - 2ms/step
# Epoch 2/13
# 407/407 - 0s - loss: 0.0231 - accuracy: 0.0025 - 301ms/epoch - 740us/step
# Epoch 3/13
# 407/407 - 0s - loss: 0.0061 - accuracy: 0.0025 - 297ms/epoch - 731us/step
# Epoch 4/13
# 407/407 - 0s - loss: 0.0032 - accuracy: 0.0025 - 302ms/epoch - 743us/step
# Epoch 5/13
# 407/407 - 0s - loss: 0.0023 - accuracy: 0.0025 - 299ms/epoch - 735us/step
# Epoch 6/13
# 407/407 - 0s - loss: 0.0016 - accuracy: 0.0025 - 301ms/epoch - 740us/step
# Epoch 7/13
# 407/407 - 0s - loss: 0.0013 - accuracy: 0.0025 - 296ms/epoch - 727us/step
# Epoch 8/13
# 407/407 - 0s - loss: 9.6193e-04 - accuracy: 0.0025 - 306ms/epoch - 751us/step
# Epoch 9/13
# 407/407 - 0s - loss: 8.8459e-04 - accuracy: 0.0025 - 302ms/epoch - 743us/step
# Epoch 10/13
# 407/407 - 0s - loss: 7.2773e-04 - accuracy: 0.0025 - 317ms/epoch - 780us/step
# Epoch 11/13
# 407/407 - 0s - loss: 8.2373e-04 - accuracy: 0.0025 - 304ms/epoch - 746us/step
# Epoch 12/13
# 407/407 - 0s - loss: 6.3041e-04 - accuracy: 0.0025 - 304ms/epoch - 746us/step
# Epoch 13/13
# 407/407 - 0s - loss: 5.6615e-04 - accuracy: 0.0025 - 304ms/epoch - 748us/step

# %% [markdown]
# #### 7. Prediction using Trained ANN Model

# %%
inputsB = btc_adjClose[len(btc_adjClose)-len(btc_test)-80:].values 
inputsB = inputsB.reshape(-1,1) 
inputsB = scaler.transform(inputsB)

# %%
x_test = []
for i in range(80,inputsB.shape[0]):
    x_test.append(inputsB[i-80:i,0]) 
x_test = np.array(x_test) 
print('Before: ',x_test.shape) 
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1])) 
print('After: ',x_test.shape) 
closing_price = model.predict(x_test) 
closing_price = scaler.inverse_transform(closing_price)
# Out:
# Before:  (122, 80)
# After:  (122, 80)
# 4/4 [==============================] - 0s 2ms/step

# %% [markdown]
# #### 8. Evaluating the predictions

# %%
# RMSE for ANN
rmse = np.sqrt(np.mean(np.power((btc_test['Adj_Close'].values-closing_price),2))) 
print(f'RMSE for ANN : {rmse:.6f}') 

# MAPE for ANN 

mape = np.mean(np.abs(closing_price-btc_test['Adj_Close'].values)/np.abs(btc_test['Adj_Close'].values)) 
print(f'MAPE for ANN : {mape:.6f}') 

# MPE for ANN 

mpe = np.mean((closing_price-btc_test['Adj_Close'].values)/btc_test['Adj_Close'].values) 
print(f'MPE for ANN : {mpe:.6f}')
# Out:
# RMSE for ANN : 2552.167281
# MAPE for ANN : 0.215971
# MPE for ANN : -0.127777

# %% [markdown]
# #### 9. Correlation between actual values and predicted via ANN

# %%
btc_test['ANN_Predictions'] = closing_price 

corr_ANN = np.corrcoef(btc_test['ANN_Predictions'].dropna().values, btc_test['Adj_Close'].dropna().values)[0,1] 
print(f'Correlation between ANN and actual values : {corr_ANN*100:.2f}%')
# Out:
# Correlation between ANN and actual values : 91.43%

# %% [markdown]
# #### 10. Plotting the predictions from LSTM w.r.t Test values

# %%
plt.figure(figsize=(20,7)) 
ax = plt.axes() 
ax.xaxis.set_major_locator(plt.MaxNLocator(20)) 
plt.plot(btc_train['Adj_Close'],label='BTC_Training_Close')
plt.plot(btc_test['Adj_Close'],label='BTC_Test_Close')
plt.plot(btc_test['ANN_Predictions'],label='ANN_Predictions') 
plt.xlabel('Date') 
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) 
plt.ylabel('Price') 
plt.title('ANN Forecast Plot (recreate)') 
ax.grid(True) 
plt.legend(loc='best') 
plt.show()
